# %%
import os
import h5py
import pandas as pd

import matplotlib.pyplot as plt

# %%
nexus = "/SNS/VENUS/IPTS-34969/nexus/VENUS_7122.nxs.h5"
assert os.path.exists(nexus)

with h5py.File(nexus, 'r') as hdf5_data:

    bm_event_index = hdf5_data['entry']['monitor1']['event_index'][:]
    bm_event_time_offset = hdf5_data['entry']['monitor1']['event_time_offset'][:]
    bm_event_time_zero = hdf5_data['entry']['monitor1']['event_time_zero'][:]

# %%
bm_event_time_offset[1]
# Out:
# 26326.6

# %%
plt.plot(bm_event_index[0:100])

# %%
plt.plot(bm_event_time_offset[0:100])

# %%
plt.plot(bm_event_time_zero[0:100])
