# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
x_axis = np.array([116.73, 121.73, 106.73, 111.73])
y_axis = np.array([107.08, 112.08, 117.08, 122.08])

x_axis.sort()
y_axis.sort()

# %%
class C1:
    v116_73 = 0
    v121_73 = 1
    v106_73 = 2
    v111_73 = 3

class C2:
    v107_08 = 0
    v112_08 = 1
    v117_08 = 2
    v122_08 = 3

# %%
data_4_by_4 = np.empty((4, 4))
data_4_by_4[C1.v116_73, C2.v107_08] = 423.3
data_4_by_4[C1.v116_73, C2.v112_08] = 242.9
data_4_by_4[C1.v116_73, C2.v117_08] = 131.2 
data_4_by_4[C1.v121_73, C2.v107_08] = 431.7
data_4_by_4[C1.v121_73, C2.v112_08] = 246.1
data_4_by_4[C1.v121_73, C2.v117_08] = 131.4
data_4_by_4[C1.v116_73, C2.v122_08] = 213.8
data_4_by_4[C1.v116_73, C2.v117_08] = 135.9
data_4_by_4[C1.v106_73, C2.v122_08] = 228.8
data_4_by_4[C1.v111_73, C2.v122_08] = 217.7
data_4_by_4[C1.v116_73, C2.v122_08] = 213.8
data_4_by_4[C1.v121_73, C2.v122_08] = 207.8
data_4_by_4[C1.v106_73, C2.v122_08] = 233
data_4_by_4[C1.v111_73, C2.v122_08] = 218.2
data_4_by_4[C1.v116_73, C2.v122_08] = 214.2
data_4_by_4[C1.v121_73, C2.v122_08] = 207.1

# %%
fig, ax = plt.subplots()
img = ax.imshow(data_4_by_4, cmap='viridis')
plt.colorbar(img)

# %%
# Best position for thermal 4x4
C1 = 116.73
C2 = 117.08
